# %% [markdown]
# # Probability exercises

# %% [markdown]
# ### Exercise 1
#
# Two unbiased dice are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7
#
# We could use a mathematical equation to solve this or we can run the experiment many times, and then count the number of times where the score is even or greater than 7
#
# -Run the experiment 1000 times (roll 2 dice 1000 times, and sum the result)
#
# -Keep track of the number of times that the sum was either greater than 7 or an even number
#
# -Divide the number from step 2 by the number of iterations (1000)

# %%
#import libraries

import numpy as np

#Funtion to roll the dice.

def roll_dice(n):
    list=[]
    for i in range (n):
        dice1 = np.random.randint(1,6)
        dice2 = np.random.randint(1,6)
        suma = dice1 + dice2
        if suma%2==0 or suma>7:
            list.append(1)
    return sum(list)/n

# %%
print("La probabilidad estimada es de:", round(roll_dice(1000)*100,2),"%")
# Out:
# La probabilidad estimada es de: 67.8 %

# %% [markdown]
# ### Exercise 2
#
# A box contains 10 white balls, 20 reds and 30 greens. Draw 5 balls with replacement. What is the probability that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color
#
#
# We will use the same system here. We will pick our balls during each round and count the number of times that:
#
# a. 3 white or 2 red
#
# b. All 5 are the same color.

# %%
#import libraries

import numpy as np

d = {}

for i in range(60):
    if i < 10:
        d[i] = 'White'
    elif i > 9 and i < 30:
        d[i] = 'Red'
    else:
        d[i] = 'Green'

# %%
#Initialize important variables

n_simulations=1000
parte_a=0
parte_b=0
parte_c=0



for i in range(n_simulations):

    #make a list of the colors that we choose

    list=[]

    for i in range(5):
        color = d[np.random.randint(0,59)]
        list.append(color)
    
    #print(list)
    #Convert it to a numpy array

    arr=np.array(list)
    #print(arr)
   
    #find the number of each taht we picked

    white = sum(arr == 'White')
    red = sum(arr == 'Red')
    green = sum(arr == 'Green')
    
    #print(white)
    #Keep track if the combination met the criteria

    if white ==3 and red==2:
        parte_a +=1
    elif white ==5 or red==5 or green==5:
        parte_b +=1
    elif white ==3 or red==2:
        parte_c +=1   
    
    
    
print('the probability of 3 white and 2 red is', round((parte_a/n_simulations)*100,2), "%")

print('the probability of 3 white or 2 red is', round((parte_c/n_simulations)*100,2), "%")

print('the probability of all the same color is', round((parte_b/n_simulations)*100,2), '%')
# Out:
# the probability of 3 white and 2 red is 0.9 %
# the probability of 3 white or 2 red is 38.0 %
# the probability of all the same color is 3.8 %
